# %%
import os

os.environ["HF_HOME"] = "/root/autodl-tmp/HF_download"
os.environ["MODELSCOPE_CACHE"] = "/root/autodl-tmp/MODELSCOPE_download"
# os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-0.6B")

# %%
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained(
    "Qwen/Qwen3-0.6B",
).to("cuda")

# %%
model.generation_config
# Out:
# GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "temperature": 0.6,
#   "top_k": 20,
#   "top_p": 0.95
# }

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0, do_sample=True)
# Out:
# Device set to use cuda:0

# %%
pipe("你好")
# Out:
# [{'generated_text': '你好Question，用户输入的内容可能包含一些不规则的语法结构，比如省略号、标点符号、空格或数字。我需要先检查这些内容并去除它们。比如，"hello, how are you?"中的标点符号和空格应该被去除。然后，将剩下的内容按照用户的要求进行处理。最后，将处理后的结果返回给用户。\n好的，我现在需要处理用户的输入内容。首先，我要仔细阅读用户的问题，确保理解所有要求。用户提到，输入的内容可能包含不规则的语法结构，比如省略号、标点符号、空格或数字。我的任务是先检查这些内容并去除它们，然后按照用户的要求进行处理，最后返回处理后的结果。\n\n接下来，我需要考虑如何去除这些不规则的语法结构。可能的步骤包括：\n\n1. **识别和去除省略号**：在文本中找到并删除所有出现的“...”。\n2. **处理标点符号**：例如，将逗号、句号、问号等标点符号去除。\n3. **处理空格和数字**：将空格和数字字符也去除。\n4. **检查是否有其他需要处理的内容**：比如，可能还有其他'}]
