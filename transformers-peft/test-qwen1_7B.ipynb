# %%
import os

os.environ["HF_HOME"] = "/root/autodl-tmp/HF_download"
os.environ["MODELSCOPE_CACHE"] = "/root/autodl-tmp/MODELSCOPE_download"
# os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-1.7B-Base")

# %%
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained(
    "Qwen/Qwen3-1.7B-Base",
).to("cuda")

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0, do_sample=True)
# Out:
# Device set to use cuda:0

# %%
pipe("你好")
# Out:
# [{'generated_text': '你好，我是上个月26号流血的，然后现在还有一点点，我担心是不是怀孕了。 您好！如果您在上个月26号流血后仍有少量出血，这可能是由多种原因引起的。首先，流产后可能会有持续的小量出血，这是正常的恢复过程的一部分。然而，如果出血量增加、颜色变深或伴有其他症状（如腹痛、发热等），则可能需要考虑怀孕的可能性。\n\n为了确定是否怀孕，您可以进行以下步骤：\n\n1. **验孕测试**：购买一种家用验孕棒进行自我检测。大多数验孕棒可以在预计月经开始的第一天之后使用，以获得更准确的结果。如果测试结果为阴性但您的月经仍未来潮，建议等待几天后再次测试或咨询医生。\n\n2. **咨询医生**：如果您担心自己的健康状况或者验孕结果不确定，最好联系医疗专业人员进行进一步的评估和指导。\n\n3. **了解其他可能性**：除了怀孕外，还有其他可能导致流产后出血的因素，比如子宫内膜异位症、感染或其他妇科问题。因此，定期的妇科检查也是很重要的。\n\n请记住，每个人的恢复情况都是独特的，如果您有任何疑问或担忧，及时寻求医生的帮助是非常'}]
