# %%
import os

os.environ["HF_HOME"] = "/root/autodl-tmp/HF_download"
os.environ["MODELSCOPE_CACHE"] = "/root/autodl-tmp/MODELSCOPE_download"
os.environ["HF_TOKEN"] = "xxx"
# os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"

# %%
import numpy
print("numpy:", numpy.__version__)

# %%
import torch
print("torch:", torch.__version__)

# %%
import transformers
print("transformers:", transformers.__version__)

# %%
from transformers import AutoTokenizer, AutoModel

# %%
tokenizer = AutoTokenizer.from_pretrained("/root/autodl-tmp/MODELSCOPE_download/models/ZhipuAI/chatglm3-6b", trust_remote_code=True)
tokenizer

# %%
import torch

model = AutoModel.from_pretrained("/root/autodl-tmp/MODELSCOPE_download/models/ZhipuAI/chatglm3-6b", trust_remote_code=True, low_cpu_mem_usage=True, torch_dtype=torch.half, device_map="auto")

# %%
model.chat(tokenizer, "考试的技巧有哪些？", history=[])
